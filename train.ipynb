# %%
from tool.config import Cfg
from model.trainer import Trainer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6c7305d9486e> in <module>
#       1 from tool.config import Cfg
# ----> 2 from model.trainer import Trainer
#
# /media/hoangnt/Data1/Projects/Meditech/document-ocr/model/trainer.py in <module>
# ----> 1 from vietocr.optim.optim import ScheduledOptim
#       2 from vietocr.optim.labelsmoothingloss import LabelSmoothingLoss
#       3 from torch.optim import Adam, SGD, AdamW
#       4 from torch import nn
#       5 from vietocr.tool.translate import build_model
#
# ModuleNotFoundError: No module named 'vietocr'

# %%
config = Cfg.load_config_from_name('vgg_transformer')

# %%
dataset_params = {
    'name':'my_data',
    'data_root':'datasets',
    'train_annotation':'train.txt',
    'valid_annotation':'val.txt'
}

params = {
         'print_every':200,
         'valid_every':15*200,
          'iters':20000,
          'checkpoint':'./checkpoint/my_transformer.pth',    
          'export':'./weights/my_transformer.pth',
          'metrics': 10000
         }

config['trainer'].update(params)
config['dataset'].update(dataset_params)
config['device'] = 'cuda:0'

# %%
config
# Out:
# {'pretrain': {'id_or_url': '13327Y1tz1ohsm5YZMyXVMPIOjoOA0OaA',
#   'md5': 'fbefa85079ad9001a71eb1bf47a93785',
#   'cached': '/tmp/tranformerorc.pth'},
#  'weights': 'https://drive.google.com/uc?id=13327Y1tz1ohsm5YZMyXVMPIOjoOA0OaA',
#  'backbone': 'vgg19_bn',
#  'cnn': {'ss': [[2, 2], [2, 2], [2, 1], [2, 1], [1, 1]],
#   'ks': [[2, 2], [2, 2], [2, 1], [2, 1], [1, 1]],
#   'hidden': 256},
#  'vocab': 'aAàÀảẢãÃáÁạẠăĂằẰẳẲẵẴắẮặẶâÂầẦẩẨẫẪấẤậẬbBcCdDđĐeEèÈẻẺẽẼéÉẹẸêÊềỀểỂễỄếẾệỆfFgGhHiIìÌỉỈĩĨíÍịỊjJkKlLmMnNoOòÒỏỎõÕóÓọỌôÔồỒổỔỗỖốỐộỘơƠờỜởỞỡỠớỚợỢpPqQrRsStTuUùÙủỦũŨúÚụỤưƯừỪửỬữỮứỨựỰvVwWxXyYỳỲỷỶỹỸýÝỵỴzZ0123456789!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ ',
#  'device': 'cuda:0',
#  'seq_modeling': 'transformer',
#  'transformer': {'d_model': 256,
#   'nhead': 8,
#   'num_encoder_layers': 6,
#   'num_decoder_layers': 6,
#   'dim_feedforward': 2048,
#   'max_seq_length': 1024,
#   'pos_dropout': 0.1,
#   'trans_dropout': 0.1},
#  'optimizer': {'init_lr': 0.1, 'n_warmup_steps': 4000},
#  'trainer': {'batch_size': 32,
#   'print_every': 200,
#   'valid_every': 3000,
#   'iters': 20000,
#   'export': './weights/my_transformer.pth',
#   'checkpoint': './checkpoint/my_transformer.pth',
#   'log': './train.log',
#   'metrics': 10000},
#  'dataset': {'name': 'my_data',
#   'data_root': 'datasets',
#   'train_annotation': 'train.txt',
#   'valid_annotation': 'val.txt',
#   'image_height': 32,
#   'image_min_width': 32,
#   'image_max_width': 512},
#  'dataloader': {'num_workers': 3, 'pin_memory': True},
#  'predictor': {'beamsearch': False},
#  'quiet': False}

# %%
trainer = Trainer(config)
# Out:
# Cached Downloading: /tmp/tranformerorc.pth
# Downloading...
# From: https://drive.google.com/uc?id=13327Y1tz1ohsm5YZMyXVMPIOjoOA0OaA
# To: /home/hoangnt/.cache/gdown/tmptaa3nmgm/dl
# 152MB [00:14, 10.3MB/s]
# Computing MD5: /tmp/tranformerorc.pth
# MD5 matches: /tmp/tranformerorc.pth
# train_my_data exists. Remove folder if you want to create new dataset
# train_my_data build cluster: 100%|████████████████████████████| 250/250 [00:00<00:00, 143561.88it/s]
# Create valid_my_data: 100%|█████████████████████████████████████| 151/151 [00:00<00:00, 3947.62it/s]
# valid_my_data build cluster: 100%|█████████████████████████████| 150/150 [00:00<00:00, 53503.33it/s]
# Created dataset with 150 samples

# %%
trainer.train()
# Out:
# iter: 000200 - train loss: 1.046 - lr: 4.94e-06 - load time: 5.06 - gpu time: 84.68
# iter: 000400 - train loss: 0.863 - lr: 9.88e-06 - load time: 5.35 - gpu time: 86.17
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-3435b262f1ae> in <module>
# ----> 1 trainer.train()
#
# /media/hoangnt/Data1/Projects/Meditech/vietocr/model/trainer.py in train(self)
#      98
#      99             start = time.time()
# --> 100             loss = self.step(batch)
#     101             total_gpu_time += time.time() - start
#     102
#
# /media/hoangnt/Data1/Projects/Meditech/vietocr/model/trainer.py in step(self, batch)
#     313         loss.backward()
#     314
# --> 315         self.optimizer.step()
#     316
#     317         loss_item = loss.item()
#
# ~/.virtualenvs/research/lib/python3.6/site-packages/vietocr/optim/optim.py in step(self)
#      15         "Step with the inner optimizer"
#      16         self._update_learning_rate()
# ---> 17         self._optimizer.step()
#      18
#      19
#
# ~/.virtualenvs/research/lib/python3.6/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      13         def decorate_context(*args, **kwargs):
#      14             with self:
# ---> 15                 return func(*args, **kwargs)
#      16         return decorate_context
#      17
#
# ~/.virtualenvs/research/lib/python3.6/site-packages/torch/optim/adam.py in step(self, closure)
#      98                 # Decay the first and second moment running average coefficient
#      99                 exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
# --> 100                 exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#     101                 if amsgrad:
#     102                     # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:

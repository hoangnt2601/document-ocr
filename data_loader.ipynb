# %%
from tool.config import Cfg
import torchvision
import os
import lmdb
from tqdm import tqdm
import numpy as np
import cv2

# %%
def writeCache(env, cache):
    with env.begin(write=True) as txn:
        for k, v in cache.items():
            txn.put(k.encode(), v)
            
def checkImageIsValid(imageBin):
    isvalid = True
    imgH = None
    imgW = None

    imageBuf = np.fromstring(imageBin, dtype=np.uint8)
    try:
        img = cv2.imdecode(imageBuf, cv2.IMREAD_GRAYSCALE)

        imgH, imgW = img.shape[0], img.shape[1]
        if imgH * imgW == 0:
            isvalid = False
    except Exception as e:
        isvalid = False

    return isvalid, imgH, imgW

# %%
config = Cfg.load_config_from_name('vgg_transformer')

# %%
dataset_params = {
    'name':'my_data',
    'data_root':'datasets',
    'train_annotation':'train.txt',
    'valid_annotation':'val.txt'
}

params = {
         'print_every':200,
         'valid_every':15*200,
          'iters':20000,
          'checkpoint':'./checkpoint/my_transformer.pth',    
          'export':'./weights/my_transformer.pth',
          'metrics': 10000
         }

config['trainer'].update(params)
config['dataset'].update(dataset_params)
config['device'] = 'cuda:0'

# %%
config
# Out:
# {'pretrain': {'id_or_url': '13327Y1tz1ohsm5YZMyXVMPIOjoOA0OaA',
#   'md5': 'fbefa85079ad9001a71eb1bf47a93785',
#   'cached': '/tmp/tranformerorc.pth'},
#  'weights': 'https://drive.google.com/uc?id=13327Y1tz1ohsm5YZMyXVMPIOjoOA0OaA',
#  'backbone': 'vgg19_bn',
#  'cnn': {'ss': [[2, 2], [2, 2], [2, 1], [2, 1], [1, 1]],
#   'ks': [[2, 2], [2, 2], [2, 1], [2, 1], [1, 1]],
#   'hidden': 256},
#  'vocab': 'aAàÀảẢãÃáÁạẠăĂằẰẳẲẵẴắẮặẶâÂầẦẩẨẫẪấẤậẬbBcCdDđĐeEèÈẻẺẽẼéÉẹẸêÊềỀểỂễỄếẾệỆfFgGhHiIìÌỉỈĩĨíÍịỊjJkKlLmMnNoOòÒỏỎõÕóÓọỌôÔồỒổỔỗỖốỐộỘơƠờỜởỞỡỠớỚợỢpPqQrRsStTuUùÙủỦũŨúÚụỤưƯừỪửỬữỮứỨựỰvVwWxXyYỳỲỷỶỹỸýÝỵỴzZ0123456789!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ ',
#  'device': 'cuda:0',
#  'seq_modeling': 'transformer',
#  'transformer': {'d_model': 256,
#   'nhead': 8,
#   'num_encoder_layers': 6,
#   'num_decoder_layers': 6,
#   'dim_feedforward': 2048,
#   'max_seq_length': 1024,
#   'pos_dropout': 0.1,
#   'trans_dropout': 0.1},
#  'optimizer': {'init_lr': 0.1, 'n_warmup_steps': 4000},
#  'trainer': {'batch_size': 32,
#   'print_every': 200,
#   'valid_every': 3000,
#   'iters': 20000,
#   'export': './weights/my_transformer.pth',
#   'checkpoint': './checkpoint/my_transformer.pth',
#   'log': './train.log',
#   'metrics': 10000},
#  'dataset': {'name': 'my_data',
#   'data_root': 'datasets',
#   'train_annotation': 'train.txt',
#   'valid_annotation': 'val.txt',
#   'image_height': 32,
#   'image_min_width': 32,
#   'image_max_width': 512},
#  'dataloader': {'num_workers': 3, 'pin_memory': True},
#  'predictor': {'beamsearch': False},
#  'quiet': False}

# %%
data_root = config['dataset']['data_root']
train_annotation = config['dataset']['train_annotation']
valid_annotation = config['dataset']['valid_annotation']
vocab = config['vocab']
dataset_name = config['dataset']['name']

# %%
transforms = torchvision.transforms.Compose([
    torchvision.transforms.ColorJitter(brightness=.1, contrast=.1, hue=.1, saturation=.1),
    torchvision.transforms.RandomAffine(degrees=0, scale=(3/4, 4/3))
])

# %%
lmdb_path='train_{}'.format(dataset_name)
root_dir=data_root
annotation_path = os.path.join(root_dir, train_annotation)
image_height=config['dataset']['image_height']
image_min_width=config['dataset']['image_min_width']
image_max_width=config['dataset']['image_max_width']

# %%
with open(annotation_path, 'r') as ann_file:
    lines = ann_file.readlines()
    annotations = [l.strip().split('\t') for l in lines]

# %%
annotations
# Out:
# [['images/1602473935.6425607.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.6505153.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.6596978.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.6647706.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.671753.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.6909418.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.7086434.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.713762.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.7318375.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.7396367.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.7458189.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.7673876.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.7770083.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.7841415.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.8060265.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.8121328.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.9753742.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.9825265.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473935.9967763.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.0034585.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.0221672.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.0273013.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.0322225.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.0390375.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.0454402.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.0622988.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.0792367.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.0853307.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.0903513.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.094605.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.0998206.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.1094525.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.1164982.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.1225848.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.129728.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.1346352.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.1397274.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.1606507.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.1658125.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.171987.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.1777112.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.1912203.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.1969316.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.2027133.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.2083972.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.213935.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.2195837.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.2271643.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.2501395.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.2565558.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.2624793.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.2671156.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.274019.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.2825134.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.3133209.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.31925.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.3395154.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.3452995.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.3516352.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.357694.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.3627818.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.3677528.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.3729887.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.3783054.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.384804.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.446368.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.4531386.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.4710543.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.4772656.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.4828732.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.4974682.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.5036323.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.5102072.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.5160184.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.5366359.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.541422.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.5475893.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.553487.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.5591073.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.577893.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.5869381.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.6138244.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.6234322.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.6279979.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.6336932.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.639488.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.6464214.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.6594973.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.6642988.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.6704955.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.6893911.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.6942523.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.7140253.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.7270465.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.7470133.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.755159.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.760717.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.7742603.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.794069.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.800102.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.8056521.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.8120048.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.818895.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.825801.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.8330474.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.850564.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.8686266.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.8743265.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.891537.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.896477.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.9022188.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.9252722.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.9304812.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.93913.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.962537.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473936.968727.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.1307988.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.138082.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.1521068.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.1590118.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.1767573.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.1821961.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.187206.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.1934476.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.1995907.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.2160935.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.2321727.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.2431104.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.2480729.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.2519472.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.2571807.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.2632463.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.2845862.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.2923455.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.2990072.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.3039157.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.3087502.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.329664.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.3347583.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.3415415.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.3470278.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.3598378.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.3655334.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.370994.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.3765175.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.382216.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.3879445.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.3935666.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.4140153.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.4202356.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.4261537.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.4306707.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.4397986.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.44486.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.4758415.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.4819367.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.5017536.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.507859.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.5164254.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.5227153.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.527703.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.5326052.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.5378978.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.543271.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.5497892.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.6166706.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.6231205.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.6408293.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.6475437.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.654949.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.6676643.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.67409.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.6797101.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.6849449.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.703896.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.7086263.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.7149215.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.7210422.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.7261848.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.7438943.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.753217.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.771921.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.7785153.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.7826989.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.788167.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.7930965.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.7995956.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.8124752.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.8169794.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.8246906.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.842274.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.8467093.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.8657508.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.87898.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.897971.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.9066968.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.9118433.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.9242575.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.9480681.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.9540164.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.9598134.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.9659111.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.972206.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.9773452.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473937.9840562.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.0015678.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.0199826.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.025272.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.0421388.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.0476.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.0534139.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.074105.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.0790088.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.0854433.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.1046827.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.1110318.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.267095.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.2745755.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.294646.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.3012605.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.3188593.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.325589.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.3304493.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.336619.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.3428812.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.3598201.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.3761518.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.3822281.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.3872056.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.3914335.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.3966935.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.4037693.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.4125464.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.4186552.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.427273.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.4331799.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.4417498.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.461611.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.4668868.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.4729939.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.4785967.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.4917235.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.4976952.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.503348.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.5091558.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.5148969.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.5210369.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.5265706.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.5450613.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.5521107.jpg', 'Hoàng đẹp trai'],
#  ['images/1602473938.5620787.jpg', 'Hoàng đẹp trai']]

# %%
lmdb_path
# Out:
# 'train_my_data'

# %%
nSamples = len(annotations)
env = lmdb.open(lmdb_path, map_size=1099511627776)
cache = {}
cnt = 0
error = 0

pbar = tqdm(range(nSamples), ncols = 100, desc='Create {}'.format(lmdb_path)) 
for i in pbar:
    imageFile, label = annotations[i]
    imagePath = os.path.join(root_dir, imageFile)

    if not os.path.exists(imagePath):
        print("Not exists path ", imagePath)
        error += 1
        continue

    with open(imagePath, 'rb') as f:
        imageBin = f.read()
    isvalid, imgH, imgW = checkImageIsValid(imageBin)
    
    if not isvalid:
        print("Image is not valid ", imagePath)
        error += 1
        continue

    imageKey = 'image-%09d' % cnt
    labelKey = 'label-%09d' % cnt
    pathKey = 'path-%09d' % cnt
    dimKey = 'dim-%09d' % cnt

    cache[imageKey] = imageBin
    cache[labelKey] = label.encode()
    cache[pathKey] = imageFile.encode()
    cache[dimKey] = np.array([imgH, imgW], dtype=np.int32).tobytes()

    cnt += 1

    if cnt % 1000 == 0:
        writeCache(env, cache)
        cache = {}
nSamples = cnt-1
cache['num-samples'] = str(nSamples).encode()
writeCache(env, cache)
# Out:
# Create train_my_data:   0%|                                                 | 0/251 [00:00<?, ?it/s]/home/hoangnt/.virtualenvs/research/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   # This is added back by InteractiveShellApp.init_path()
# Create train_my_data: 100%|█████████████████████████████████████| 251/251 [00:00<00:00, 4742.40it/s]

# %%
env = lmdb.open(
    lmdb_path,
    max_readers=8,
    readonly=True,
    lock=False,
    readahead=False,
    meminit=False)

# %%
txn = env.begin(write=False)

# %%
nSamples = int(txn.get('num-samples'.encode()))

# %%
nSamples
# Out:
# 250
